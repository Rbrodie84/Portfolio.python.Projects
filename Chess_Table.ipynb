# %%
import pandas as pd

# %%
chess_games = pd.read_csv('chess_games.csv')

# %%
chess_games.head()
# Out:
#                 Event            White       Black Result     UTCDate  \
# 0          Classical           eisaaaa    HAMID449    1-0  2016.06.30
# 1              Blitz            go4jas  Sergei1973    0-1  2016.06.30
# 2   Blitz tournament   Evangelistaizac      kafune    1-0  2016.06.30
# 3     Correspondence            Jvayne    Wsjvayne    1-0  2016.06.30
# 4   Blitz tournament            kyoday   BrettDale    0-1  2016.06.30
#
#     UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  ECO  \
# 0  22:00:01      1901      1896             11.0            -11.0  D10
# 1  22:00:01      1641      1627            -11.0             12.0  C20
# 2  22:00:02      1647      1688             13.0            -13.0  B01
# 3  22:00:02      1706      1317             27.0            -25.0  A00
# 4  22:00:02      1945      1900            -14.0             13.0  B90
#
#                                          Opening TimeControl   Termination  \
# ...

# %%
chess_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6256184 entries, 0 to 6256183
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Event            object
#  1   White            object
#  2   Black            object
#  3   Result           object
#  4   UTCDate          object
#  5   UTCTime          object
#  6   WhiteElo         int64
#  7   BlackElo         int64
#  8   WhiteRatingDiff  float64
#  9   BlackRatingDiff  float64
#  10  ECO              object
#  11  Opening          object
#  12  TimeControl      object
#  13  Termination      object
#  14  AN               object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 716.0+ MB

# %%
chess_nulls = chess_games.isnull().sum()

# %%
chess_nulls
# Out:
# Event                 0
# White                 0
# Black                 0
# Result                0
# UTCDate               0
# UTCTime               0
# WhiteElo              0
# BlackElo              0
# WhiteRatingDiff    4668
# BlackRatingDiff    4668
# ECO                   0
# Opening               0
# TimeControl           0
# Termination           0
# AN                    0
# dtype: int64

# %%
chess_games['WhiteRatingDiff']
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 6256179    False
# 6256180    False
# 6256181    False
# 6256182    False
# 6256183    False
# Name: WhiteRatingDiff, Length: 6256184, dtype: bool

# %%
chess_games['Event'].unique()
# Out:
# array([' Classical ', ' Blitz ', ' Blitz tournament ', ' Correspondence ',
#        ' Classical tournament ', ' Bullet tournament ', ' Bullet ',
#        'Blitz tournament ', 'Bullet ', 'Classical ', 'Blitz ',
#        'Bullet tournament ', 'Classical tournament ', 'Correspondence '],
#       dtype=object)

# %%
chess_games['AN'].unique()
# Out:
# array(['1. d4 d5 2. c4 c6 3. e3 a6 4. Nf3 e5 5. cxd5 e4 6. Ne5 cxd5 7. Qa4+ Bd7 8. Nxd7 Nxd7 9. Nc3 Nf6 10. Qb3 Be7 11. Nxd5 Qa5+ 12. Nc3 O-O 13. Be2 b5 14. O-O Rad8 15. Bd2 Qc7 16. Rac1 Qd6 17. Qc2 Qe6 18. Nb1 Bd6 19. a3 Nb6 20. Qc6 Nfd5 21. Ba5 Rc8 22. Qb7 Qh6 23. h3 Nc4 24. Bxc4 bxc4 25. Qxd5 Rfd8 26. Qxe4 Rd7 27. Bc3 Re7 28. Qf3 Re6 29. Nd2 Rf6 30. Qg4 Re8 31. Ne4 Rg6 32. Qd7 Rf8 33. Nxd6 Rxd6 34. Qc7 Rg6 35. Qh2 Re8 36. d5 f6 37. d6 Rd8 38. Rfd1 1-0',
#        '1. e4 e5 2. b3 Nf6 3. Bb2 Nc6 4. Nf3 d6 5. d3 g6 6. Nbd2 Bg7 7. g3 Be6 8. Bg2 Qd7 9. O-O O-O 10. c3 b5 11. d4 exd4 12. cxd4 Bg4 13. Rc1 Rfe8 14. Qc2 Nb4 15. Qxc7 Qxc7 16. Rxc7 Nxa2 17. Ra1 Nb4 18. Raxa7 Rxa7 19. Rxa7 Nxe4 20. Nxe4 Rxe4 21. Ng5 Re1+ 22. Bf1 Be2 23. Rxf7 Bxf1 24. Kh1 Bh3# 0-1',
# ...

# %%
chess_games.columns
# Out:
# Index(['Event', 'White', 'Black', 'Result', 'UTCDate', 'UTCTime', 'WhiteElo',
#        'BlackElo', 'WhiteRatingDiff', 'BlackRatingDiff', 'ECO', 'Opening',
#        'TimeControl', 'Termination', 'AN'],
#       dtype='object')

# %%
len(chess_games['White'].unique())
# Out:
# 118945

# %%
len(chess_games['Black'].unique())
# Out:
# 115946

# %%
len(chess_games['Opening'].unique())
# Out:
# 2942

# %%
len(chess_games['ECO'].unique())
# Out:
# 493

# %%
chess_games['ECO']
# Out:
# 0          D10
# 1          C20
# 2          B01
# 3          A00
# 4          B90
#           ...
# 6256179    B54
# 6256180    C40
# 6256181    B21
# 6256182    A09
# 6256183    C00
# Name: ECO, Length: 6256184, dtype: object

# %%
chess_games.columns
# Out:
# Index(['Event', 'White', 'Black', 'Result', 'UTCDate', 'UTCTime', 'WhiteElo',
#        'BlackElo', 'WhiteRatingDiff', 'BlackRatingDiff', 'ECO', 'Opening',
#        'TimeControl', 'Termination', 'AN'],
#       dtype='object')

# %%
chess_games['Termination'].unique()
# Out:
# array(['Time forfeit', 'Normal', 'Abandoned', 'Rules infraction',
#        'Unterminated'], dtype=object)

# %%
chess_games.head(10)
# Out:
#                 Event            White            Black Result     UTCDate  \
# 0          Classical           eisaaaa         HAMID449    1-0  2016.06.30
# 1              Blitz            go4jas       Sergei1973    0-1  2016.06.30
# 2   Blitz tournament   Evangelistaizac           kafune    1-0  2016.06.30
# 3     Correspondence            Jvayne         Wsjvayne    1-0  2016.06.30
# 4   Blitz tournament            kyoday        BrettDale    0-1  2016.06.30
# 5   Blitz tournament    lucaseixasouza           diguim    0-1  2016.06.30
# 6   Blitz tournament          RENZZO77  HeadlessChicken    0-1  2016.06.30
# 7   Blitz tournament             ipero        Bayern123    1-0  2016.06.30
# 8   Blitz tournament   Loginov19510410          Kereshu    0-1  2016.06.30
# 9   Blitz tournament        Shambobala       cernunnoss    1-0  2016.06.30
#
#     UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  ECO  \
# ...

# %%
type(chess_games)
# Out:
# pandas.core.frame.DataFrame

# %%
null_list = chess_games.isnull().any(axis=1)

# %%
null_rows = chess_games[null_list]

# %%
null_rows
# Out:
#                Event               White           Black Result     UTCDate  \
# 205           Blitz         irakli112233      irakli1811    1-0  2016.06.30
# 388           Blitz         irakli112233      irakli1811    1-0  2016.06.30
# 3352          Blitz              ZUMOSOL  pawnimpact0007    1-0  2016.06.30
# 4452      Classical   IvanIsPlayingChess    ChessCurry30    0-1  2016.06.30
# 4564          Blitz          MagusMaster  pawnimpact0007    1-0  2016.06.30
# ...              ...                 ...             ...    ...         ...
# 6246093   Classical           Love_Pound        MELLAMAN    0-1  2016.07.31
# 6248289   Classical                  cnv        Pounds_0    0-1  2016.07.31
# 6248556       Blitz            abilove94        maryam21    0-1  2016.07.31
# 6249759   Classical            abilove94  canadiancenter    1-0  2016.07.31
# 6251200   Classical                Lu4ik        Pounds_O    0-1  2016.07.31
#
# ...

# %%
chess_games['WhiteRatingDiff'].head(100)
# Out:
# 0     11.0
# 1    -11.0
# 2     13.0
# 3     27.0
# 4    -14.0
#       ...
# 95   -15.0
# 96    12.0
# 97    22.0
# 98    21.0
# 99    -7.0
# Name: WhiteRatingDiff, Length: 100, dtype: float64

# %%
chess_games2 = chess_games.dropna()

# %%
chess_games2['UTCDate'] = pd.to_datetime(chess_games2['UTCDate'])
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_6463/599015163.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2['UTCDate'] = pd.to_datetime(chess_games2['UTCDate'])

# %%
chess_games2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6251516 entries, 0 to 6256183
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Event            object
#  1   White            object
#  2   Black            object
#  3   Result           object
#  4   UTCDate          datetime64[ns]
#  5   UTCTime          object
#  6   WhiteElo         int64
#  7   BlackElo         int64
#  8   WhiteRatingDiff  float64
#  9   BlackRatingDiff  float64
#  10  ECO              object
#  11  Opening          object
#  12  TimeControl      object
#  13  Termination      object
#  14  AN               object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(10)
# memory usage: 763.1+ MB

# %%
chess_games2['UTCTime'] = pd.to_datetime(chess_games2['UTCTime'], format='%H:%M:%S')
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_6463/285855864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2['UTCTime'] = pd.to_datetime(chess_games2['UTCTime'], format='%H:%M:%S')

# %%
chess_games2['UTCTime'].dt.time
# Out:
# 0          22:00:01
# 1          22:00:01
# 2          22:00:02
# 3          22:00:02
# 4          22:00:02
#              ...
# 6256179    21:59:56
# 6256180    21:59:54
# 6256181    21:59:53
# 6256182    21:59:57
# 6256183    21:59:54
# Name: UTCTime, Length: 6251516, dtype: object

# %%
chess_games2[['Game_Time', 'Game_Delay']] = chess_games2['TimeControl'].str.split('+',expand=True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3295131978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2[['Game_Time', 'Game_Delay']] = chess_games2['TimeControl'].str.split('+',expand=True)
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3295131978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2[['Game_Time', 'Game_Delay']] = chess_games2['TimeControl'].str.split('+',expand=True)

# %%
chess_games2.head(3)
# Out:
#                 Event            White       Black Result     UTCDate  \
# 0          Classical           eisaaaa    HAMID449    1-0  2016.06.30
# 1              Blitz            go4jas  Sergei1973    0-1  2016.06.30
# 2   Blitz tournament   Evangelistaizac      kafune    1-0  2016.06.30
#
#     UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  ECO  \
# 0  22:00:01      1901      1896             11.0            -11.0  D10
# 1  22:00:01      1641      1627            -11.0             12.0  C20
# 2  22:00:02      1647      1688             13.0            -13.0  B01
#
#                                          Opening TimeControl   Termination  \
# 0                                   Slav Defense       300+5  Time forfeit
# 1                      King's Pawn Opening: 2.b3       300+0        Normal
# 2  Scandinavian Defense: Mieses-Kotroc Variation       180+0  Time forfeit
#
#                                                   AN Game_Time Game_Delay
# ...

# %%
chess_games2.drop('TimeControl', axis = 1)
# Out:
#                       Event                 White           Black Result  \
# 0                Classical                eisaaaa        HAMID449    1-0
# 1                    Blitz                 go4jas      Sergei1973    0-1
# 2         Blitz tournament        Evangelistaizac          kafune    1-0
# 3           Correspondence                 Jvayne        Wsjvayne    1-0
# 4         Blitz tournament                 kyoday       BrettDale    0-1
# ...                     ...                   ...             ...    ...
# 6256179              Blitz             GustavScar         WEBRIFF    1-0
# 6256180          Classical                 apgaro         Camposf    1-0
# 6256181             Bullet   matematico1234567890  cecile_creteil    0-1
# 6256182             Bullet            MagnusMinor          shegap    0-1
# 6256183          Classical              SocratAss          KOSMA7    0-1
#
#             UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  \
# ...

# %%
chess_games2.drop('Termination', axis = 1)
# Out:
#                       Event                 White           Black Result  \
# 0                Classical                eisaaaa        HAMID449    1-0
# 1                    Blitz                 go4jas      Sergei1973    0-1
# 2         Blitz tournament        Evangelistaizac          kafune    1-0
# 3           Correspondence                 Jvayne        Wsjvayne    1-0
# 4         Blitz tournament                 kyoday       BrettDale    0-1
# ...                     ...                   ...             ...    ...
# 6256179              Blitz             GustavScar         WEBRIFF    1-0
# 6256180          Classical                 apgaro         Camposf    1-0
# 6256181             Bullet   matematico1234567890  cecile_creteil    0-1
# 6256182             Bullet            MagnusMinor          shegap    0-1
# 6256183          Classical              SocratAss          KOSMA7    0-1
#
#             UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  \
# ...

# %%
chess_games2.drop('AN', axis = 1)
# Out:
#                       Event                 White           Black Result  \
# 0                Classical                eisaaaa        HAMID449    1-0
# 1                    Blitz                 go4jas      Sergei1973    0-1
# 2         Blitz tournament        Evangelistaizac          kafune    1-0
# 3           Correspondence                 Jvayne        Wsjvayne    1-0
# 4         Blitz tournament                 kyoday       BrettDale    0-1
# ...                     ...                   ...             ...    ...
# 6256179              Blitz             GustavScar         WEBRIFF    1-0
# 6256180          Classical                 apgaro         Camposf    1-0
# 6256181             Bullet   matematico1234567890  cecile_creteil    0-1
# 6256182             Bullet            MagnusMinor          shegap    0-1
# 6256183          Classical              SocratAss          KOSMA7    0-1
#
#             UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  \
# ...

# %%
chess_games2[['White_Wins', 'Black_Wins']] = chess_games2['Result'].str.split('-',expand=True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3219320138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2[['White_Wins', 'Black_Wins']] = chess_games2['Result'].str.split('-',expand=True)
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3219320138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2[['White_Wins', 'Black_Wins']] = chess_games2['Result'].str.split('-',expand=True)

# %%
chess_games2.head(3)
# Out:
#                 Event            White       Black Result     UTCDate  \
# 0          Classical           eisaaaa    HAMID449    1-0  2016.06.30
# 1              Blitz            go4jas  Sergei1973    0-1  2016.06.30
# 2   Blitz tournament   Evangelistaizac      kafune    1-0  2016.06.30
#
#     UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  ECO  \
# 0  22:00:01      1901      1896             11.0            -11.0  D10
# 1  22:00:01      1641      1627            -11.0             12.0  C20
# 2  22:00:02      1647      1688             13.0            -13.0  B01
#
#                                          Opening TimeControl   Termination  \
# 0                                   Slav Defense       300+5  Time forfeit
# 1                      King's Pawn Opening: 2.b3       300+0        Normal
# 2  Scandinavian Defense: Mieses-Kotroc Variation       180+0  Time forfeit
#
#                                                   AN Game_Time Game_Delay  \
# ...

# %%
chess_games2.drop('AN', axis = 1, inplace = True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/1060809622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2.drop('AN', axis = 1, inplace = True)

# %%
chess_games2.drop('Termination', axis = 1, inplace=True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3577128061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2.drop('Termination', axis = 1, inplace=True)

# %%
chess_games2.drop('Result', axis = 1, inplace=True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/575519128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2.drop('Result', axis = 1, inplace=True)

# %%
chess_games2.drop('TimeControl', axis = 1, inplace=True)
# Out:
# /var/folders/9_/0fspnqrs77nd9dttq1q9_rv40000gn/T/ipykernel_7203/3858627349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chess_games2.drop('TimeControl', axis = 1, inplace=True)

# %%
chess_games2.to_csv(index_label = 'Game_Number')
